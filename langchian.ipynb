# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm_model=ChatGoogleGenerativeAI(google_api_key=os.getenv("GOOGLE_API_KEY"),temperature=0.6,model="gemini-2.5-flash")
text= "what is the difference between langchain and openai?"
response=llm_model.invoke(text)
print(response.text)
# Out:
# The difference between LangChain and OpenAI is fundamental: they operate at different layers of the AI stack and serve distinct purposes.
#
# Think of it this way:
#
# *   **OpenAI provides the "brain" (the raw intelligence).**
# *   **LangChain provides the "body" and "nervous system" to make that brain useful in a complex application.**
#
# Let's break it down:
#
# ---
#
# ### OpenAI
#
# *   **What it is:** A leading AI research and deployment company.
# *   **What it provides:**
#     *   **Large Language Models (LLMs):** Like GPT-3, GPT-3.5, GPT-4 (text generation, summarization, translation, coding, etc.).
#     *   **Image Generation Models:** Like DALL-E (generating images from text prompts).
#     *   **Speech-to-Text Models:** Like Whisper (transcribing audio).
#     *   **APIs:** It provides programmatic access to these powerful AI models through APIs (Application Programming Interfaces).
# *   **Core Purpose:** To develop and deliver cutting-edge AI models that can understand, generate, and interact with human-like data. It's the **source of the AI intelligence itself.**
# *   **Proprietary:** OpenAI's models are proprietary (though they offer open-source tools like Whisper). You access them via their paid API service.
#
# **In summary: OpenAI is the *producer* and *provider* of powerful, foundational AI models.**
#
# ---
#
# ### LangChain
#
# *   **What it is:** An open-source framework or library.
# *   **What it provides:**
#     *   **Abstractions and Tools:** It offers a structured way to build applications that are powered by LLMs. It's not an LLM itself.
#     *   **Components for LLM Applications:**
#         *   **Chains:** Sequences of calls to LLMs or other utilities.
#         *   **Agents:** LLMs that can reason, observe, and take actions using tools (like searching the web, calling APIs, running code).
#         *   **Memory:** For persistent state in conversations.
#         *   **Retrieval:** For integrating external data sources (like your own documents) with LLMs (e.g., for Retrieval Augmented Generation - RAG).
#         *   **Tools:** Standardized interfaces for LLMs to interact with external resources.
#     *   **LLM Agnostic:** While it frequently integrates with OpenAI's models, LangChain is designed to work with *any* LLM provider (Google's PaLM/Gemini, Anthropic's Claude, open-source models like Llama, etc.).
# *   **Core Purpose:** To simplify and accelerate the development of complex, data-aware, and agentic applications *using* LLMs. It's the **orchestrator and glue that connects LLMs with other data sources and tools.**
#
# **In summary: LangChain is a *developer toolkit* for building sophisticated applications *on top of* AI models like those provided by OpenAI.**
#
# ---
#
# ### Key Differences at a Glance
#
# | Feature        | OpenAI                                     | LangChain                                       |
# | :------------- | :----------------------------------------- | :---------------------------------------------- |
# | **Type**       | AI Research Company, Model Provider        | Open-source Framework/Library                   |
# | **Purpose**    | Develop & provide AI models                | Build applications *with* AI models             |
# | **Output**     | AI models (GPT, DALL-E, Whisper) & APIs    | Application logic, components, workflows        |
# | **Role**       | The intelligence, the "brain"              | The orchestrator, the "body" & "nervous system" |
# | **Dependency** | Independent (develops its own models)      | Often *uses* OpenAI (and other LLMs)           |
# | **Cost**       | Pay-per-use for API access                 | Free (open-source), but you pay for underlying LLMs |
#
# ---
#
# ### How They Work Together
#
# Most commonly, developers use **LangChain to build applications that leverage OpenAI's models.**
#
# For example:
#
# 1.  You want to build a chatbot that can answer questions about your company's internal documents.
# 2.  You would use **OpenAI's GPT-4** as the underlying language model to understand questions and generate answers.
# 3.  You would use **LangChain** to:
#     *   Connect to the GPT-4 API.
#     *   Load your company documents, chunk them, and embed them.
#     *   Set up a "retrieval chain" so that when a user asks a question, relevant document snippets are retrieved and passed to GPT-4 along with the question (RAG).
#     *   Manage the conversation history ("memory") so GPT-4 remembers previous turns.
#     *   Potentially give GPT-4 "tools" to search the web if it can't find the answer in your documents.
#
# In this scenario, OpenAI provides the raw intelligence, and LangChain provides the structure and functionality to make that intelligence useful in a specific, complex application.
